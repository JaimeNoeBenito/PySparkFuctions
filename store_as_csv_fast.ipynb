# %%
__author__      = "Jaime Benito"
__version__     = "1.0.1"
__maintainer__  = "Jaime Benito"
__status__      = "Prod - Development"
__description__ = "Store Data frame in single CSV file (instead of directoy - spark default)"

# %%
def store_as_csv(folderpath, filename, df, *delimit):
  if len(delimit) == 1 and delimit[0] == ";":
    df.write.format('com.databricks.spark.csv').mode('overwrite').option("header", "true").option("delimiter", ";").save(folderpath+filename)
  elif len(delimit) == 1 and delimit[0] == "|":
    df.write.format('com.databricks.spark.csv').mode('overwrite').option("header", "true").option("delimiter", "|").save(folderpath+filename)
  else:
    #df.coalesce(1).write.format('com.databricks.spark.csv').mode('overwrite').option("header", "true").option("delimiter", ",").save(folderpath+filename)
    df.write.format('com.databricks.spark.csv').mode('overwrite').option("header", "true").option("delimiter", ",").save(folderpath+filename)

  #x = folderpath+filename
  #l = dbutils.fs.ls(x) 
  #
  #for row in l: 
  #  for file in row: 
  #    file.endswith(".csv")
  #    break
#
  #index = file.index("part-00000")
  #file2=file[index:]
  #filenameNew = filename
  #dbutils.fs.mv(folderpath+filename+"/"+file2, folderpath+"/"+filenameNew+".csv")
  #dbutils.fs.rm(folderpath+filename, True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1476274301296538&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span><span class="ansi-blue-fg">()</span>
# <span class="ansi-green-intense-fg ansi-bold">     23</span>
# <span class="ansi-green-intense-fg ansi-bold">     24</span>
# <span class="ansi-green-fg">---&gt; 25</span><span class="ansi-red-fg"> </span>mergedDF <span class="ansi-blue-fg">=</span> spark<span class="ansi-blue-fg">.</span>read<span class="ansi-blue-fg">.</span>option<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;mergeSchema&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;true&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>parquet<span class="ansi-blue-fg">(</span>folderpath<span class="ansi-blue-fg">+</span>filename<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     26</span> mergedDF<span class="ansi-blue-fg">.</span>printSchema<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     27</span> mergedDF<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;com.databricks.spark.csv&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>mode<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;overwrite&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>option<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;header&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;true&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>option<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;delimiter&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;,&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>save<span class="ansi-blue-fg">(</span>folderpath<span class="ansi-blue-fg">+</span>filename<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;folderpath&#39; is not defined</div>
