# %%
fleet_MX = fleet_MX.withColumn("YM_field", F.concat(F.year("date_field"), F.lit("_"), F.lpad(F.month("date_field"),2,'0')))
fleet_MX = fleet_MX.withColumn("YM_field", F.concat(F.year("date_field"), F.lpad(F.month("date_field"),2,'0')))
