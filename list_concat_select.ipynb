# %%
list_tmp = ["field1", "field2"]
l2 = list()
for l in list_tmp:
  if(l.find("+") > 0 ):
    a = l.split("+")
    b ="CONCAT("+','.join(map(str, a))+ ") as KeyField"
    l2.append(b)
  else:
    l2.append(l)
list_a =','.join(map(str, l2))
print(list_a)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
