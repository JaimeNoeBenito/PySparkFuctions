# %%
import pyspark.sql.functions as F
from pyspark.sql.types import *

def round_X_decimal_places(df, columnList, num_decimals):
  for columName in columnList:
    df = df.withColumn(columName,F.round(df[columName], num_decimals))
  return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
