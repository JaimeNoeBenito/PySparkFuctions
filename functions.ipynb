# %%
def compareDataFrames(df1, df2):
  count1 = df1.count()
  count2 = df2.count()
  DiffCount = count1-count2
  if (abs(count1 - count2) / count1) > 0.1:
    print('KO - Perimeter')
  else:  
    print('OK - Perimeter')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
