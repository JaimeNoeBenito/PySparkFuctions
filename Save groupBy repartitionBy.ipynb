# %%
dfIn.repartition($"paritiontablefield").write.partitionBy("subparitiontablefieldsidiaryCode").mode("overwrite").option("nullValue","").option("path", p_hiveTable + my_table).saveAsTable(schema + my_table)
  spark.sql("refresh table " + schema + my_table)
