# %%
from pyspark.sql.functions import quarter
 
df1 = df_student.withColumn('quarter',quarter(df_student.birthday))
df1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df2 = df.withColumn("quarter", F.when(F.to_date(F.col("date_Field"),"dd/MM/yyyy").isNotNull(),F.to_date(F.col("date_Field"),"dd/MM/yyyy")))\
        .withColumn("quarter", F.quarter(F.col("date_Field")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
