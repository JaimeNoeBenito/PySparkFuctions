# %%
def replace_commas_by_dots(df, column_names):
  from pyspark.sql.functions import regexp_replace
  for c in column_names:
    df = df.withColumn(c, regexp_replace(c, ',', '.').cast('float'))    
  return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
##TEST
#oldColumns = ["ID", "Text"]
#data = spark.createDataFrame([("1,123","2"), ("3","4")], oldColumns)
#data.show()
#df = replace_commas_by_dots(data, oldColumns)
#df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----+
#    ID|Text|
# +-----+----+
# 1,123|   2|
#     3|   4|
# +-----+----+
#
# +-----+----+
#    ID|Text|
# +-----+----+
# 1.123| 2.0|
#   3.0| 4.0|
# +-----+----+
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
