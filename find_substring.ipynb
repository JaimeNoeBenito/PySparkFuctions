# %%
mkt_sect = df.withColumn("aaaa", F.substring_index(F.col("bbbb"),"#", 1))\
           .withColumn("bbbb", F.substring_index(F.col("dddd"),"#", -1))

# %%
ejem = 'dbfs:/mnt/asdasda/es_asdasda.zip/FFFFFFFFF_20190631_000000.csv'
folder_tmp = ejem[:len(ejem)-20]
print(folder_tmp)

folder_name = folder_tmp[folder_tmp.rfind('/')+1:]
print(folder_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dbfs:/mnt/asdasda/es_asdasda.zip/FFFFFFFFF
# FFFFFFFFF
# </div>
