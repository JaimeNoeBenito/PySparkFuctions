# %%
def padding(df, col_name, num_chars, fill_char):
  return df[col_name] = df[col_name].astype(str).str.pad(num_chars,fillchar=fill_char)

# %%
withColumn("field", F.lpad(F.col("field").cast(StringType()), 5, "0"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
