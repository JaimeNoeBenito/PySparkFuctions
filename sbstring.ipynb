# %%
ejem = 'dbfs:/mnt/dsasadsd_20190631_000000.zip/ES_dsasadsd_20190631_000000.csv'
print("Orginal\n", ejem)
print("First: \n",ejem.rsplit('_', 2)[0])
# folder_tmp = ejem[:len(ejem)-20] 
folder_tmp = ejem[:len(ejem.rsplit('_', 2)[0])] 
print("Second:\n",folder_tmp) 
folder_name = folder_tmp[folder_tmp.rfind('/')+1:] 
print("Third:\n", folder_name) 
folder_name2 = ejem[ejem.rfind('/')+1:] 
print("folder_name2 =" , folder_name2) 
# print(folder_name3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Orginal
#  dbfs:/mnt/dsasadsd_20190631_000000.zip/ES_dsasadsd_20190631_000000.csv
# First:
#  dbfs:/mnt/dsasadsd_20190631_000000.zip/ES_dsasadsd
# Second:
#  dbfs:/mnt/dsasadsd_20190631_000000.zip/ES_dsasadsd
# Third:
#  ES_dsasadsd
# folder_name2 = ES_dsasadsd_20190631_000000.csv
# </div>
