# %%
path_Fleet_in = "mypath"

Fleet_files = list(dbutils.fs.ls(path_Fleet_in))

max_date = int('19000101')
for file in aaa_files:
  if (int(file.name.replace('/', '')) > max_date):
    max_date = int(file.name.replace('/', ''))
print("Latest date:", max_date)
