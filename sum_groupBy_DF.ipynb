# %%
import pyspark.sql.functions as F
def sum_groupBy_DF(df, groupByField, sumField, aliasGroupByField):
   return df.groupBy(groupByField).agg((F.sum(F.col(sumField))).alias(aliasGroupByField))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
