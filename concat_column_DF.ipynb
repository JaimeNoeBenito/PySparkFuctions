# %%
import pyspark.sql.functions as F
fleet_MX = fleet_MX.withColumn("YM", F.concat(F.year("dateField"), F.lpad(F.month("dateField"),2,'0')))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
