# %%
import pyspark.sql.functions as F
def null_column_DF(df, aliasNewColum, columTocheck):
  return df.withColumn(aliasNewColum, F.when(F.col(columTocheck).isNull(), 1).otherwise(0))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#df = sqlContext.createDataFrame([
#    (1, "a"),
#    (2, "b"),
#    (3, None),
#], ["ID", "Text"])
#df.show()
#null_column_DF(df, "aliasNewColum", "Text").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+----+
#  ID|Text|
# +---+----+
#   1|   a|
#   2|   b|
#   3|null|
# +---+----+
#
# +---+----+-------------+
#  ID|Text|aliasNewColum|
# +---+----+-------------+
#   1|   a|            0|
#   2|   b|            0|
#   3|null|            1|
# +---+----+-------------+
#
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
