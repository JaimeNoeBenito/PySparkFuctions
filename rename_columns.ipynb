# %%
def rename_columns(df, oldColumns, newColumns):
  from pyspark.sql.functions import col
  mapping = dict(zip(oldColumns , newColumns))
  return df.select([col(c).alias(mapping.get(c, c)) for c in df.columns])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
###TEST
#oldColumns = ["ID", "Text"]
#data = spark.createDataFrame([(1,2), (3,4)], oldColumns)
#newColumns = ["name", "age"]
#df = rename_columns(data, oldColumns, newColumns)
#df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+---+
# name|age|
# +----+---+
#    1|  2|
#    3|  4|
# +----+---+
#
# </div>
