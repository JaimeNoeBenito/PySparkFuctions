# %%
volume.loc[volume['Filename'] == file.name, 'Volume'] = vol
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">If you want to paste code into IPython, try the %paste and %cpaste magic functions.
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansicyan">  File </span><span class="ansigreen">&quot;&lt;command-745746023622787&gt;&quot;</span><span class="ansicyan">, line </span><span class="ansigreen">2</span>
# ...

# %%
prev_vol = volume.where(volume["Filename"] == file.name)['Previous_Volume'][0]
