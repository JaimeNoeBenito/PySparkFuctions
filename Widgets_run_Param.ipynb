# %%
# %run /path/to/notebook $X="10" $Y="1"

# %%
dbutils.notebook.run(
  "/Users/jaimenoe.benito@XXXX.com/notebook",
  timeout_seconds = 60,
  arguments = {"margin": "3", "col1": "field2"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
