# %%
import pyspark.sql.functions as F
from pyspark.sql.types import *

def convert_column_DF_to_Double(df, columnList):
  for columName in columnList:
    df = df.withColumn(columName, df[columName].cast(DoubleType()))
  return df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
